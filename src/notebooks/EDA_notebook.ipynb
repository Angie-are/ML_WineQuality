# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
red_wine = pd.read_csv(r'C:\Users\angel\OneDrive\Documentos\DATA_SCIENCE\Bootcamp\ML_WineQuality\data\winequality-red.csv', delimiter=';')
white_wine = pd.read_csv(r'C:\Users\angel\OneDrive\Documentos\DATA_SCIENCE\Bootcamp\ML_WineQuality\data\winequality-white.csv', delimiter=';')

# %%
print("Valores nulos en el dataset de vino tinto:")
print(red_wine.isnull().sum())
print("\nValores nulos en el dataset de vino blanco:")
print(white_wine.isnull().sum())
# Out:
# Valores nulos en el dataset de vino tinto:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64
#
# Valores nulos en el dataset de vino blanco:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
sns.set(style="whitegrid")

# %%
print("Red Wine Dataset:")
print(red_wine.head())
print("\nWhite Wine Dataset:")
print(white_wine.head())
print("Red Wine Dataset Info:")
red_wine.info()
print("\nWhite Wine Dataset Info:")
white_wine.info()
# Out:
# Red Wine Dataset:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# ...

# %%
print("Red Wine Dataset Descriptive Statistics:")
print(red_wine.describe())
print("\nWhite Wine Dataset Descriptive Statistics:")
print(white_wine.describe())
# Out:
# Red Wine Dataset Descriptive Statistics:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
red_stats = red_wine.describe().transpose()
white_stats = white_wine.describe().transpose()
stats_comparison = pd.concat([red_stats['mean'], white_stats['mean']], axis=1)
stats_comparison.columns = ['Vino Tinto', 'Vino Blanco']
print(stats_comparison)
# Out:
#                       Vino Tinto  Vino Blanco
# fixed acidity           8.319637     6.854788
# volatile acidity        0.527821     0.278241
# citric acid             0.270976     0.334192
# residual sugar          2.538806     6.391415
# chlorides               0.087467     0.045772
# free sulfur dioxide    15.874922    35.308085
# total sulfur dioxide   46.467792   138.360657
# density                 0.996747     0.994027
# pH                      3.311113     3.188267
# sulphates               0.658149     0.489847
# alcohol                10.422983    10.514267
# quality                 5.636023     5.877909

# %%
features = red_wine.columns[:-1]
plt.figure(figsize=(14, 10))
for i, feature in enumerate(features):
    plt.subplot(3, 4, i+1)
    sns.histplot(red_wine[feature], kde=True, color='red', bins=20)
    plt.title(f'Distribución de {feature} - Vino Tinto')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(14, 10))
for i, feature in enumerate(features):
    plt.subplot(3, 4, i+1)
    sns.histplot(white_wine[feature], kde=True, color='blue', bins=20)
    plt.title(f'Distribución de {feature} - Vino Blanco')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.countplot(x='quality', data=red_wine, palette='coolwarm')
plt.title('Distribución de la calidad - Vino Tinto')
plt.subplot(1, 2, 2)
sns.countplot(x='quality', data=white_wine, palette='coolwarm')
plt.title('Distribución de la calidad - Vino Blanco')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_17040\4148609882.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='quality', data=red_wine, palette='coolwarm')
# C:\Users\angel\AppData\Local\Temp\ipykernel_17040\4148609882.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='quality', data=white_wine, palette='coolwarm')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='quality', y='alcohol', data=red_wine, palette='coolwarm')
plt.title('Distribución de Alcohol por Calidad - Vino Tinto')
plt.show()
plt.figure(figsize=(10, 6))
sns.boxplot(x='quality', y='alcohol', data=white_wine, palette='coolwarm')
plt.title('Distribución de Alcohol por Calidad - Vino Blanco')
plt.show()
# Out:
# C:\Users\angel\AppData\Local\Temp\ipykernel_17040\3330405576.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality', y='alcohol', data=red_wine, palette='coolwarm')
# C:\Users\angel\AppData\Local\Temp\ipykernel_17040\3330405576.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality', y='alcohol', data=white_wine, palette='coolwarm')

# %%
plt.figure(figsize=(12, 8))
for i, feature in enumerate(features):
    plt.subplot(3, 4, i+1)
    sns.boxplot(x=red_wine[feature], color='red')
    plt.title(f'Boxplot de {feature} - Vino Tinto')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
for i, feature in enumerate(features):
    plt.subplot(3, 4, i+1)
    sns.boxplot(x=white_wine[feature], color='blue')
    plt.title(f'Boxplot de {feature} - Vino Blanco')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(red_wine.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlación - Vino Tinto')
plt.show()
plt.figure(figsize=(12, 8))
sns.heatmap(white_wine.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Matriz de Correlación - Vino Blanco')
plt.show()

# %%
correlation_with_quality_red = red_wine.corr()['quality'].sort_values(ascending=False)
print("Correlación con la calidad - Vino Tinto:")
print(correlation_with_quality_red)
correlation_with_quality_white = white_wine.corr()['quality'].sort_values(ascending=False)
print("\nCorrelación con la calidad - Vino Blanco:")
print(correlation_with_quality_white)
# Out:
# Correlación con la calidad - Vino Tinto:
# quality                 1.000000
# alcohol                 0.476166
# sulphates               0.251397
# citric acid             0.226373
# fixed acidity           0.124052
# residual sugar          0.013732
# free sulfur dioxide    -0.050656
# pH                     -0.057731
# chlorides              -0.128907
# density                -0.174919
# total sulfur dioxide   -0.185100
# volatile acidity       -0.390558
# Name: quality, dtype: float64
#
# Correlación con la calidad - Vino Blanco:
# quality                 1.000000
# alcohol                 0.435575
# pH                      0.099427
# sulphates               0.053678
# free sulfur dioxide     0.008158
# citric acid            -0.009209
# residual sugar         -0.097577
# fixed acidity          -0.113663
# total sulfur dioxide   -0.174737
# volatile acidity       -0.194723
# chlorides              -0.209934
# density                -0.307123
# Name: quality, dtype: float64

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='alcohol', y='quality', data=red_wine, color='red')
plt.title('Alcohol vs Calidad - Vino Tinto')
plt.show()
plt.figure(figsize=(8, 6))
sns.scatterplot(x='alcohol', y='quality', data=white_wine, color='blue')
plt.title('Alcohol vs Calidad - Vino Blanco')
plt.show()
